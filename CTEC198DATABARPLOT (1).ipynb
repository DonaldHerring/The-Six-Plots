# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['6th Grade', '7th Grade', '8th Grade', '9th Grade', '10th Grade', '11th Grade', '12th Grade']
students = [4,6,8,15,22,26,30]
ax.bar(langs,students)
ax.set_ylabel('Number Of Abusers')
ax.set_title('Grade Level Of Drug Abusers')
plt.show()
