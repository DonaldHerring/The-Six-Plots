# %%
import matplotlib.pyplot as plt 
import numpy as np 
  
  
fig = plt.figure() 
x = np.arange(2, 70, 0.02) 
plt.plot(x, 100-x) 
  
plt.title("Abusers ") 
fig.add_subplot(2,2,4) 
plt.plot(x, 50-x) 
  
plt.title("Age") 
plt.show()
